# %%
# Definition of objects
from enum import Enum
# program to compute the time
# of execution of any python code
import time
import datetime
import pandas as pd
import numpy as np
from numpy import random
from itertools import repeat
#import matplotlib.pyplot as plt

# %%
#now
now = datetime.datetime.now()
print("Current date and time: ")
print(now.strftime('%Y-%m-%d %H:%M:%S'))
print(now.strftime('%H:%M:%S on %A, %B the %dth, %Y'))
# Out:
# Current date and time:
# 2022-07-21 04:31:51
# 04:31:51 on Thursday, July the 21th, 2022

# %%
#variable to store the starting time of execution of program
start = time.time()
print(start)
# Out:
# 1658370711.1430047

# %%
#Generate 50 random numbers from 1.100 - 1.999
a=random.randint(1100,1111, size=(50))
#afloat = random.uniform(1.100, 1.111,size=50)
print(a)
# Out:
# [1103 1105 1108 1106 1102 1104 1106 1105 1100 1103 1100 1110 1109 1103
#  1108 1110 1110 1103 1100 1106 1107 1105 1106 1106 1105 1108 1102 1109
#  1103 1104 1104 1109 1103 1108 1101 1102 1105 1110 1104 1110 1108 1102
#  1109 1106 1105 1102 1102 1103 1110 1108]

# %%
#print(afloat)

# %%
b = random.choice(['B', 'C', 'D', 'EC', 'F', 'FA-', 'FIA+', 'FICA+', 'FSA-', 'GIA', 'GSA+', 'GSA-', 'GZA-', 'H', 'K', 'L', 'LSA-', 'M',
 'MIA±', 'NC', 'P', 'PDI', 'PDICA±', 'PDIS', 'PI', 'PSA-', 'QIA+', 'QIA-', 'QSA+', 'S', 'SC', 'SIA±', 'T', 'TI', 'TIC', 'TICA±', 'TSA+',
  'V', 'W', 'WICA±', 'XA', 'Y', 'YC'], size=(50))
print(b)
# Out:
# ['B' 'T' 'LSA-' 'GSA-' 'LSA-' 'NC' 'P' 'FIA+' 'YC' 'FA-' 'FA-' 'PDICA±'
#  'W' 'FSA-' 'GSA+' 'W' 'PDI' 'SC' 'QIA-' 'C' 'TICA±' 'PDICA±' 'QSA+' 'H'
#  'PDI' 'PDICA±' 'T' 'GSA+' 'QIA+' 'PDIS' 'S' 'M' 'LSA-' 'EC' 'FSA-' 'EC'
#  'T' 'EC' 'FA-' 'PDIS' 'Y' 'F' 'B' 'WICA±' 'SC' 'W' 'SC' 'WICA±' 'FIA+'
#  'TSA+']

# %%
#Create two lists, pid and elements
pid = list(a)
elements = list(b)
len(elements)
# Out:
# 50

# %%
#Pandas version
print(pd.__version__)
# Out:
# 1.4.3

# %%
# Insert data in panda data frame for analysis and manipulation
# A Pandas Series is like a column in a table.
# It is a one-dimensional array holding data of any type.
#s = pd.Series(elements, index=pid)#Access items by name
#print(s)

# %%
#s = pd.Series(elements,pid)
#s[1100]

# %% [markdown]
# Use of Series

# %%
#Sort bx values 
#s.sort_values(axis=0,ascending=True)

# %%
#Sort by index
#s.sort_index(axis=0,ascending=True)

# %% [markdown]
# User of DataFrame

# %%
#Create a data frame from list using dictionary
dicc = {'Pid': pid,'Element': elements}
print(dicc)
# Out:
# {'Pid': [1103, 1105, 1108, 1106, 1102, 1104, 1106, 1105, 1100, 1103, 1100, 1110, 1109, 1103, 1108, 1110, 1110, 1103, 1100, 1106, 1107, 1105, 1106, 1106, 1105, 1108, 1102, 1109, 1103, 1104, 1104, 1109, 1103, 1108, 1101, 1102, 1105, 1110, 1104, 1110, 1108, 1102, 1109, 1106, 1105, 1102, 1102, 1103, 1110, 1108], 'Element': ['B', 'T', 'LSA-', 'GSA-', 'LSA-', 'NC', 'P', 'FIA+', 'YC', 'FA-', 'FA-', 'PDICA±', 'W', 'FSA-', 'GSA+', 'W', 'PDI', 'SC', 'QIA-', 'C', 'TICA±', 'PDICA±', 'QSA+', 'H', 'PDI', 'PDICA±', 'T', 'GSA+', 'QIA+', 'PDIS', 'S', 'M', 'LSA-', 'EC', 'FSA-', 'EC', 'T', 'EC', 'FA-', 'PDIS', 'Y', 'F', 'B', 'WICA±', 'SC', 'W', 'SC', 'WICA±', 'FIA+', 'TSA+']}

# %%
#df = pd.DataFrame(dicc, columns=['Element'], index=pid)
df = pd.DataFrame(dicc, columns=['Pid', 'Element'])
print(df)
# Out:
#      Pid Element
# 0   1103       B
# 1   1105       T
# 2   1108    LSA-
# 3   1106    GSA-
# 4   1102    LSA-
# 5   1104      NC
# 6   1106       P
# 7   1105    FIA+
# 8   1100      YC
# 9   1103     FA-
# 10  1100     FA-
# 11  1110  PDICA±
# 12  1109       W
# 13  1103    FSA-
# 14  1108    GSA+
# 15  1110       W
# 16  1110     PDI
# 17  1103      SC
# 18  1100    QIA-
# 19  1106       C
# 20  1107   TICA±
# 21  1105  PDICA±
# 22  1106    QSA+
# 23  1106       H
# 24  1105     PDI
# 25  1108  PDICA±
# 26  1102       T
# 27  1109    GSA+
# 28  1103    QIA+
# 29  1104    PDIS
# 30  1104       S
# 31  1109       M
# 32  1103    LSA-
# 33  1108      EC
# 34  1101    FSA-
# 35  1102      EC
# 36  1105       T
# 37  1110      EC
# 38  1104     FA-
# 39  1110    PDIS
# 40  1108       Y
# 41  1102       F
# 42  1109       B
# 43  1106   WICA±
# 44  1105      SC
# 45  1102       W
# 46  1102      SC
# 47  1103   WICA±
# 48  1110    FIA+
# 49  1108    TSA+

# %%
#refer to the row index:
#print(df.loc[min(pid)])
#print(df.loc[0])

# %%
#df_drop = df.drop_duplicates()
#df = df.drop_duplicates()

# %%
df.count()
# Out:
# Pid        50
# Element    50
# dtype: int64

# %%
#df = df.sort_index(axis=0,ascending=True)
#df = df.sort_values('Pid',ascending=True)

# %% [markdown]
# Aqui hay que sacar una lista de los elementos que se repiten en cada pid

# %%
df
# Out:
#      Pid Element
# 0   1103       B
# 1   1105       T
# 2   1108    LSA-
# 3   1106    GSA-
# 4   1102    LSA-
# 5   1104      NC
# 6   1106       P
# 7   1105    FIA+
# 8   1100      YC
# 9   1103     FA-
# 10  1100     FA-
# 11  1110  PDICA±
# 12  1109       W
# 13  1103    FSA-
# 14  1108    GSA+
# 15  1110       W
# 16  1110     PDI
# 17  1103      SC
# 18  1100    QIA-
# 19  1106       C
# 20  1107   TICA±
# 21  1105  PDICA±
# 22  1106    QSA+
# 23  1106       H
# 24  1105     PDI
# 25  1108  PDICA±
# 26  1102       T
# 27  1109    GSA+
# 28  1103    QIA+
# 29  1104    PDIS
# 30  1104       S
# 31  1109       M
# 32  1103    LSA-
# 33  1108      EC
# 34  1101    FSA-
# 35  1102      EC
# 36  1105       T
# 37  1110      EC
# 38  1104     FA-
# 39  1110    PDIS
# 40  1108       Y
# 41  1102       F
# 42  1109       B
# 43  1106   WICA±
# 44  1105      SC
# 45  1102       W
# 46  1102      SC
# 47  1103   WICA±
# 48  1110    FIA+
# 49  1108    TSA+

# %%
#df.groupby(['Pid', 'Element']).agg(list)
element_list = df.groupby(['Pid']).agg(list).copy()

# %%
type(element_list)
# Out:
# pandas.core.frame.DataFrame

# %%
element_list.count()
# Out:
# Element    11
# dtype: int64

# %%
element_list
# Out:
#                                     Element
# Pid
# 1100                        [YC, FA-, QIA-]
# 1101                                 [FSA-]
# 1102                [LSA-, T, EC, F, W, SC]
# 1103  [B, FA-, FSA-, SC, QIA+, LSA-, WICA±]
# 1104                     [NC, PDIS, S, FA-]
# 1105          [T, FIA+, PDICA±, PDI, T, SC]
# 1106           [GSA-, P, C, QSA+, H, WICA±]
# 1107                                [TICA±]
# 1108      [LSA-, GSA+, PDICA±, EC, Y, TSA+]
# 1109                        [W, GSA+, M, B]
# 1110       [PDICA±, W, PDI, EC, PDIS, FIA+]

# %%
#Return row min and max from pid:
#use a list of indexes:
element_list.loc[[min(pid),max(pid)]]
# Out:
#                                Element
# Pid
# 1100                   [YC, FA-, QIA-]
# 1110  [PDICA±, W, PDI, EC, PDIS, FIA+]

# %%
list_1100 = element_list.loc[1100].values.tolist()
list_1100[0].sort()

# %%
print(list_1100[0])
# Out:
# ['FA-', 'QIA-', 'YC']

# %%
known_elements = [['MIA±', 'PI', 'TIC', 'W'], ['GIA', 'L', 'MIA±', 'P', 'PSA-', 'W'],['B', 'FSA-', 'PDIS', 'TICA±'],['C', 'MIA±']]
#list_motor2 = ['PDI', 'D', 'QSA+']

# %%
# Using in to find whether 
# list exists or not
if list_1100[0] in known_elements:
    print("True")
else:
    print("False")
# Out:
# False

# %%
list_1100 == list_motor
# Out:
# False

# %%
#Gropby por to a list, drop duplicates
#gkk = df.groupby(['Pid', 'Element'])
  
# Print the first value in each group
#gkk.first()

# %%
#df = gkk.first()

# %%
#drop Element
#df.drop('Element', axis=1, inplace=True)

# %%
# Dropping Records Only if All Records are Missing
#df = df.dropna(how='all')
#print(df)

# %%
#find duplicates
#duplicates = df[df.duplicated('Pid')]

# %%
#duplicates

# %% [markdown]
# De aqui no nos movemos

# %%
#df_drop.sort_index(axis=0,ascending=True)

# %%
#dfsorted = df_drop.sort_index(axis=0,ascending=True)
#print(dfsorted)

# %%
#print(dfsorted.to_string())

# %%
#Add elements as columns with value NaT
#df[elements]  = '.' #pd.NaT
#print(df.to_string())

# %%
#dfsorted

#insert_element = dfsorted.loc[1101,'Element']
#print(insert_element)

#dfsorted.loc[1101,insert_element] = True
#print(dfsorted)

# %%
#for x in df.index:
#    insert_element = df.loc[x,'Element']
    #dfsorted.loc[x,insert_element] = True
#    df.loc[x,insert_element] = insert_element
 #   print(df)

# %%
#Remove row 'Element'
#df = df.drop(['Element'], axis=1)
#print(df_clean)

# %%
#Remove duplicate
#df = df.drop_duplicates()

# %%
#df = df.sort_index()

# %%
#df

# %%
#print(df_unique.to_string())

# %%
#https://www.datacamp.com/tutorial/pandas-tutorial-dataframe-python#10.-how-to-iterate-over-a-pandas-dataframe

# %%
#for pid in df_unique.index:
#    pid_to_el = df_unique.iloc[pid].drop_duplicates().to_list()
#    print(pid_to_el)

#element_list = df.values.tolist() #Create element list for each pid

#for index, row in df_unique.iterrows():
 #   pid_to_el = df_unique.iloc[index].drop_duplicates().to_list()
    #element_list.append(df_unique.iloc[index].drop_duplicates().to_list())
#    print(row['Pid'])

# %%
#element_list

# %%
#df_trans = df.transpose()

# %%
#print(df_trans.to_string())

# %%
#list_1100 = df_trans[1100].drop_duplicates().to_list()
#print(list_1100)

# %% [markdown]
# Copy a List
#
# You cannot copy a list simply by typing list2 = list1, because: list2 will only be a reference to list1, and changes made in list1 will automatically also be made in list2.

# %%
#list_motor = list_1100.copy()

# %%
#list_motor = list_1100
#list_1100.remove('.')
#list_1100.sort()
#print(list_motor)

# %%
#list_motor

# %%
#list_1100

# %%
#list_1100 == list_motor
