# %%
# Definition of objects
from enum import Enum
# program to compute the time
# of execution of any python code
import time
import datetime
import pandas as pd
import numpy as np
from numpy import random
from itertools import repeat
#import matplotlib.pyplot as plt

# %%
#now
now = datetime.datetime.now()
print("Current date and time: ")
print(now.strftime('%Y-%m-%d %H:%M:%S'))
print(now.strftime('%H:%M:%S on %A, %B the %dth, %Y'))
# Out:
# Current date and time:
# 2022-07-21 01:41:09
# 01:41:09 on Thursday, July the 21th, 2022

# %%
#variable to store the starting time of execution of program
start = time.time()
print(start)
# Out:
# 1658360470.0381832

# %%
#Generate 50 random numbers from 1.100 - 1.999
a=random.randint(1100,1111, size=(50))

print(a)
# Out:
# [1107 1109 1106 1102 1105 1103 1105 1100 1108 1103 1102 1100 1108 1106
#  1109 1106 1107 1106 1105 1109 1110 1105 1109 1109 1107 1100 1110 1106
#  1109 1109 1101 1103 1106 1106 1108 1104 1109 1106 1101 1101 1105 1101
#  1106 1106 1101 1106 1101 1104 1108 1101]

# %%
b = random.choice(['B', 'C', 'D', 'EC', 'F', 'FA-', 'FIA+', 'FICA+', 'FSA-', 'GIA', 'GSA+', 'GSA-', 'GZA-', 'H', 'K', 'L', 'LSA-', 'M',
 'MIA±', 'NC', 'P', 'PDI', 'PDICA±', 'PDIS', 'PI', 'PSA-', 'QIA+', 'QIA-', 'QSA+', 'S', 'SC', 'SIA±', 'T', 'TI', 'TIC', 'TICA±', 'TSA+',
  'V', 'W', 'WICA±', 'XA', 'Y', 'YC'], size=(50))
print(b)
# Out:
# ['QIA+' 'T' 'PI' 'GZA-' 'PI' 'K' 'MIA±' 'D' 'GIA' 'Y' 'PDIS' 'PDI' 'M'
#  'PDI' 'PSA-' 'XA' 'GIA' 'Y' 'LSA-' 'FICA+' 'PDI' 'PI' 'FSA-' 'SC' 'S'
#  'QSA+' 'EC' 'PI' 'LSA-' 'PDI' 'GSA+' 'B' 'QSA+' 'GZA-' 'TSA+' 'FSA-' 'V'
#  'K' 'C' 'TSA+' 'TICA±' 'TI' 'SC' 'GIA' 'GSA+' 'C' 'S' 'PDIS' 'P' 'FA-']

# %%
#Create two lists, pid and elements
pid = list(a)
elements = list(b)
len(elements)
# Out:
# 50

# %%
#Pandas version
print(pd.__version__)
# Out:
# 1.4.3

# %%
# Insert data in panda data frame for analysis and manipulation
# A Pandas Series is like a column in a table.
# It is a one-dimensional array holding data of any type.
#s = pd.Series(elements, index=pid)#Access items by name
#print(s)

# %%
#s = pd.Series(elements,pid)
#s[1100]

# %% [markdown]
# Use of Series

# %%
#Sort bx values 
#s.sort_values(axis=0,ascending=True)

# %%
#Sort by index
#s.sort_index(axis=0,ascending=True)

# %% [markdown]
# User of DataFrame

# %%
#Create a data frame from list using dictionary
dicc = {'Pid': pid,'Element': elements}
print(dicc)
# Out:
# {'Pid': [1107, 1109, 1106, 1102, 1105, 1103, 1105, 1100, 1108, 1103, 1102, 1100, 1108, 1106, 1109, 1106, 1107, 1106, 1105, 1109, 1110, 1105, 1109, 1109, 1107, 1100, 1110, 1106, 1109, 1109, 1101, 1103, 1106, 1106, 1108, 1104, 1109, 1106, 1101, 1101, 1105, 1101, 1106, 1106, 1101, 1106, 1101, 1104, 1108, 1101], 'Element': ['QIA+', 'T', 'PI', 'GZA-', 'PI', 'K', 'MIA±', 'D', 'GIA', 'Y', 'PDIS', 'PDI', 'M', 'PDI', 'PSA-', 'XA', 'GIA', 'Y', 'LSA-', 'FICA+', 'PDI', 'PI', 'FSA-', 'SC', 'S', 'QSA+', 'EC', 'PI', 'LSA-', 'PDI', 'GSA+', 'B', 'QSA+', 'GZA-', 'TSA+', 'FSA-', 'V', 'K', 'C', 'TSA+', 'TICA±', 'TI', 'SC', 'GIA', 'GSA+', 'C', 'S', 'PDIS', 'P', 'FA-']}

# %%
#df = pd.DataFrame(dicc, columns=['Element'], index=pid)
df = pd.DataFrame(dicc, columns=['Pid', 'Element'])
print(df)
# Out:
#      Pid Element
# 0   1107    QIA+
# 1   1109       T
# 2   1106      PI
# 3   1102    GZA-
# 4   1105      PI
# 5   1103       K
# 6   1105    MIA±
# 7   1100       D
# 8   1108     GIA
# 9   1103       Y
# 10  1102    PDIS
# 11  1100     PDI
# 12  1108       M
# 13  1106     PDI
# 14  1109    PSA-
# 15  1106      XA
# 16  1107     GIA
# 17  1106       Y
# 18  1105    LSA-
# 19  1109   FICA+
# 20  1110     PDI
# 21  1105      PI
# 22  1109    FSA-
# 23  1109      SC
# 24  1107       S
# 25  1100    QSA+
# 26  1110      EC
# 27  1106      PI
# 28  1109    LSA-
# 29  1109     PDI
# 30  1101    GSA+
# 31  1103       B
# 32  1106    QSA+
# 33  1106    GZA-
# 34  1108    TSA+
# 35  1104    FSA-
# 36  1109       V
# 37  1106       K
# 38  1101       C
# 39  1101    TSA+
# 40  1105   TICA±
# 41  1101      TI
# 42  1106      SC
# 43  1106     GIA
# 44  1101    GSA+
# 45  1106       C
# 46  1101       S
# 47  1104    PDIS
# 48  1108       P
# 49  1101     FA-

# %%
#refer to the row index:
#print(df.loc[min(pid)])
#print(df.loc[0])

# %%
#df_drop = df.drop_duplicates()
#df = df.drop_duplicates()

# %%
df.count()
# Out:
# Pid        50
# Element    50
# dtype: int64

# %%
#df = df.sort_index(axis=0,ascending=True)
#df = df.sort_values('Pid',ascending=True)

# %% [markdown]
# Aqui hay que sacar una lista de los elementos que se repiten en cada pid

# %%
df
# Out:
#      Pid Element
# 0   1107    QIA+
# 1   1109       T
# 2   1106      PI
# 3   1102    GZA-
# 4   1105      PI
# 5   1103       K
# 6   1105    MIA±
# 7   1100       D
# 8   1108     GIA
# 9   1103       Y
# 10  1102    PDIS
# 11  1100     PDI
# 12  1108       M
# 13  1106     PDI
# 14  1109    PSA-
# 15  1106      XA
# 16  1107     GIA
# 17  1106       Y
# 18  1105    LSA-
# 19  1109   FICA+
# 20  1110     PDI
# 21  1105      PI
# 22  1109    FSA-
# 23  1109      SC
# 24  1107       S
# 25  1100    QSA+
# 26  1110      EC
# 27  1106      PI
# 28  1109    LSA-
# 29  1109     PDI
# 30  1101    GSA+
# 31  1103       B
# 32  1106    QSA+
# 33  1106    GZA-
# 34  1108    TSA+
# 35  1104    FSA-
# 36  1109       V
# 37  1106       K
# 38  1101       C
# 39  1101    TSA+
# 40  1105   TICA±
# 41  1101      TI
# 42  1106      SC
# 43  1106     GIA
# 44  1101    GSA+
# 45  1106       C
# 46  1101       S
# 47  1104    PDIS
# 48  1108       P
# 49  1101     FA-

# %%
#df.groupby(['Pid', 'Element']).agg(list)
element_list = df.groupby(['Pid']).agg(list).copy()

# %%
type(element_list)
# Out:
# pandas.core.frame.DataFrame

# %%
element_list.count()
# Out:
# Element    11
# dtype: int64

# %%
print(element_list)
# Out:
#                                               Element
# Pid
# 1100                                   [D, PDI, QSA+]
# 1101                [GSA+, C, TSA+, TI, GSA+, S, FA-]
# 1102                                     [GZA-, PDIS]
# 1103                                        [K, Y, B]
# 1104                                     [FSA-, PDIS]
# 1105                      [PI, MIA±, LSA-, PI, TICA±]
# 1106  [PI, PDI, XA, Y, PI, QSA+, GZA-, K, SC, GIA, C]
# 1107                                   [QIA+, GIA, S]
# 1108                                [GIA, M, TSA+, P]
# 1109         [T, PSA-, FICA+, FSA-, SC, LSA-, PDI, V]
# 1110                                        [PDI, EC]

# %%
#Return row min and max from pid:
#use a list of indexes:
print(element_list.loc[[min(pid),max(pid)]])
# Out:
#              Element
# Pid
# 1100  [D, PDI, QSA+]
# 1110       [PDI, EC]

# %%
list_1100 = element_list.loc[1100].values.tolist()
list_1100
# Out:
# [['D', 'PDI', 'QSA+']]

# %%
list_motor = [['D', 'PDI', 'QSA+']]

# %%
# Using in to find whether 
# list exists or not
if list_1100 in list_motor:
    print("True")
else:
    print("False")
# Out:
# False

# %%
list_1100 == list_motor
# Out:
# False

# %%
#Gropby por to a list, drop duplicates
#gkk = df.groupby(['Pid', 'Element'])
  
# Print the first value in each group
#gkk.first()

# %%
#df = gkk.first()

# %%
#drop Element
#df.drop('Element', axis=1, inplace=True)

# %%
# Dropping Records Only if All Records are Missing
#df = df.dropna(how='all')
#print(df)

# %%
#find duplicates
#duplicates = df[df.duplicated('Pid')]

# %%
#duplicates

# %% [markdown]
# De aqui no nos movemos

# %%
#df_drop.sort_index(axis=0,ascending=True)

# %%
#dfsorted = df_drop.sort_index(axis=0,ascending=True)
#print(dfsorted)

# %%
#print(dfsorted.to_string())

# %%
#Add elements as columns with value NaT
#df[elements]  = '.' #pd.NaT
#print(df.to_string())

# %%
#dfsorted

#insert_element = dfsorted.loc[1101,'Element']
#print(insert_element)

#dfsorted.loc[1101,insert_element] = True
#print(dfsorted)

# %%
#for x in df.index:
#    insert_element = df.loc[x,'Element']
    #dfsorted.loc[x,insert_element] = True
#    df.loc[x,insert_element] = insert_element
 #   print(df)

# %%
#Remove row 'Element'
#df = df.drop(['Element'], axis=1)
#print(df_clean)

# %%
#Remove duplicate
#df = df.drop_duplicates()

# %%
#df = df.sort_index()

# %%
#df

# %%
#print(df_unique.to_string())

# %%
#https://www.datacamp.com/tutorial/pandas-tutorial-dataframe-python#10.-how-to-iterate-over-a-pandas-dataframe

# %%
#for pid in df_unique.index:
#    pid_to_el = df_unique.iloc[pid].drop_duplicates().to_list()
#    print(pid_to_el)

#element_list = df.values.tolist() #Create element list for each pid

#for index, row in df_unique.iterrows():
 #   pid_to_el = df_unique.iloc[index].drop_duplicates().to_list()
    #element_list.append(df_unique.iloc[index].drop_duplicates().to_list())
#    print(row['Pid'])

# %%
#element_list

# %%
#df_trans = df.transpose()

# %%
#print(df_trans.to_string())

# %%
#list_1100 = df_trans[1100].drop_duplicates().to_list()
#print(list_1100)

# %% [markdown]
# Copy a List
#
# You cannot copy a list simply by typing list2 = list1, because: list2 will only be a reference to list1, and changes made in list1 will automatically also be made in list2.

# %%
#list_motor = list_1100.copy()

# %%
#list_motor = list_1100
#list_1100.remove('.')
#list_1100.sort()
#print(list_motor)

# %%
#list_motor

# %%
#list_1100

# %%
#list_1100 == list_motor
